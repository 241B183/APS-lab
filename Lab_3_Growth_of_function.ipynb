# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )
def even_odd_count(numbers):
    even_count = 0
    odd_count = 0
    for num in numbers:
        if num % 2 == 0:
            even_count += 1
        else:
            odd_count += 1
    return even_count

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#Prob_3:Take another example and write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)
def even_odd_count(numbers):
    even_count = 0
    odd_count = 0
    for num in numbers:
        if num % 2 == 0:
            even_count += 1
        else:
            odd_count += 1
    return
plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example.
import math

def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1

n_values = list(range(1, 101))
time_values_log = []

for n in n_values:
    data = list(range(n))
    # Simulate the operation (binary search doesn't get slower with n directly in this time measurement way)
    # The actual 'time' for O(log n) is proportional to log(n)
    if n > 0: # Avoid log(0)
        time_values_log.append(math.log(n))
    else:
        time_values_log.append(0)

plt.figure()
plt.plot(n_values, time_values_log)
plt.xlabel("Input size n")
plt.ylabel("Time (log n)")
plt.title("O(log n) Logarithmic Time Complexity")
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.
import math

def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)

    return merge(left_half, right_half)

def merge(left, right):
    result = []
    left_idx, right_idx = 0, 0

    while left_idx < len(left) and right_idx < len(right):
        if left[left_idx] < right[right_idx]:
            result.append(left[left_idx])
            left_idx += 1
        else:
            result.append(right[right_idx])
            right_idx += 1

    result.extend(left[left_idx:])
    result.extend(right[right_idx:])
    return result

n_values = list(range(1, 101))
time_values_n_log_n = []

for n in n_values:
    data = list(range(n, 0, -1)) # Create a reversed list for a 'worst-case' sort scenario
    # Simulate the time complexity for O(n log n)
    if n > 1: # Avoid log(0) or log(1) issues, as for n=1, n*log(n) is 0
        time_values_n_log_n.append(n * math.log(n))
    else:
        time_values_n_log_n.append(0)

plt.figure()
plt.plot(n_values, time_values_n_log_n)
plt.xlabel("Input size n")
plt.ylabel("Time (n log n)")
plt.title("O(n log n) Log-Linear Time Complexity")
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
def quadratic_function(n):
    total = 0
    for i in range(n):
        for j in range(n):
            total += 1
    return total
plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n^2) Polynomial Time Complexity")
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in exponential time. plot the graph as well, similar to above example
def fibonacci(n):
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)

# For exponential complexity, n needs to be small, otherwise computation time is too long
n_values_exp = list(range(1, 20))  # Limiting n for exponential calculation
time_values_exp = []

for n in n_values_exp:
    # Simulate the time complexity for O(2^n)
    time_values_exp.append(2**n)

plt.figure()
plt.plot(n_values_exp, time_values_exp)
plt.xlabel("Input size n")
plt.ylabel("Time (2^n)")
plt.title("O(2^n) Exponential Time Complexity")
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3073412158.py in <cell line: 0>()
#       4 x = np.array
#       5 y = np.array
# ----> 6 plt.plot(x,y)
#       7 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778         for line in lines:
# -> 1779             self.add_line(line)
#    1780         if scalex:
#    1781             self._request_autoscale_view("x")
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in add_line(self, line)
#    2369             line.set_clip_path(self.patch)
#    2370
# -> 2371         self._update_line_limits(line)
#    2372         if not line.get_label():
#    2373             line.set_label(f'_child{len(self._children)}')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    2392         Figures out the data limit of the given line, updating `.Axes.dataLim`.
#    2393         """
# -> 2394         path = line.get_path()
#    2395         if path.vertices.size == 0:
#    2396             return
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/lines.py in get_path(self)
#    1036         """Return the `~matplotlib.path.Path` associated with this line."""
#    1037         if self._invalidy or self._invalidx:
# -> 1038             self.recache()
#    1039         return self._path
#    1040
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/lines.py in recache(self, always)
#     673         if always or self._invalidx:
#     674             xconv = self.convert_xunits(self._xorig)
# --> 675             x = _to_unmasked_float_array(xconv).ravel()
#     676         else:
#     677             x = self._x
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _to_unmasked_float_array(x)
#    1343         return np.ma.asarray(x, float).filled(np.nan)
#    1344     else:
# -> 1345         return np.asarray(x, float)
#    1346
#    1347
#
# TypeError: float() argument must be a string or a real number, not 'builtin_function_or_method'

# %%
# Write a function to perform quick sort and show that it has Log-Linear Time Complexity O(n log n) on average.
import math
import random

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[random.randint(0, len(arr) - 1)] # Choose a random pivot
        less = [x for x in arr if x < pivot]
        equal = [x for x in arr if x == pivot]
        greater = [x for x in arr if x > pivot]
        return quick_sort(less) + equal + quick_sort(greater)

n_values_quick_sort = list(range(1, 101))
time_values_quick_sort = []

for n in n_values_quick_sort:
    # Simulate the time complexity for O(n log n)
    if n > 1: # Avoid log(0) or log(1) issues, as for n=1, n*log(n) is 0
        time_values_quick_sort.append(n * math.log(n))
    else:
        time_values_quick_sort.append(0)

plt.figure()
plt.plot(n_values_quick_sort, time_values_quick_sort)
plt.xlabel("Input size n")
plt.ylabel("Time (n log n)")
plt.title("O(n log n) Quick Sort Average Time Complexity")
plt.show()
